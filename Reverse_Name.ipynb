# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaron-KS/Python/blob/main/Reverse_Name.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = "champion"

print(x)
# Out:
# champion

# %%
print(x[0])
# Out:
# c

# %%
print(x[0:4])
# Out:
# cham

# %%
print(x[0:5])
# Out:
# champ

# %%
print(x[-1])
# Out:
# n

# %%
print(x[-4])
# Out:
# p

# %%
print(x[::2])   #0:2
# Out:
# capo

# %%
print("bright + champs")
# Out:
# bright + champs

# %%
print("bright "*3)
# Out:
# bright bright bright

# %%
x = "I am happy"
for i in x:       #accesing every character
  print(i)
# Out:
# I
#
# a
# m
#
# h
# a
# p
# p
# y

# %%
#other ways applying loops
x = "hello world"
for i in range(0, len(x)):
  print(x[i], end="")
# Out:
# hello world

# %%
len(x)
# Out:
# 11

# %%
x = "hello world"
for i in range(-1, -len(x)-1, -1):     #reverce order
  print(x[i], end="")
# Out:
# dlrow olleh

# %%
print(-len(x)-1)
# Out:
# -12
